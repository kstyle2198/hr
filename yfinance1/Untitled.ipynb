# %%
import yfinance as fn
import urllib
import json

# %%
def get_yahoo_shortname(symbol):
    response = urllib.request.urlopen(f'https://query2.finance.yahoo.com/v1/finance/search?q={symbol}')
    content = response.read()
    data = json.loads(content.decode('utf8'))#['quotes'][0]['shortname']
    return data

# %%
get_yahoo_shortname("CAT")
# Out:
# {'explains': [],
#  'count': 16,
#  'quotes': [{'exchange': 'NYQ',
#    'shortname': 'Caterpillar, Inc.',
#    'quoteType': 'EQUITY',
#    'symbol': 'CAT',
#    'index': 'quotes',
#    'score': 3516700.0,
#    'typeDisp': 'Equity',
#    'longname': 'Caterpillar Inc.',
#    'exchDisp': 'NYSE',
#    'sector': 'Industrials',
#    'industry': 'Farm & Heavy Construction Machinery',
#    'dispSecIndFlag': False,
#    'isYahooFinance': True},
#   {'exchange': 'NYQ',
#    'shortname': 'Catalent, Inc.',
#    'quoteType': 'EQUITY',
#    'symbol': 'CTLT',
#    'index': 'quotes',
#    'score': 54430.0,
#    'typeDisp': 'Equity',
#    'longname': 'Catalent, Inc.',
#    'exchDisp': 'NYSE',
#    'sector': 'Healthcare',
#    'industry': 'Drug Manufacturers—Specialty & Generic',
#    'isYahooFinance': True},
#   {'exchange': 'CME',
#    'shortname': 'Live Cattle Futures,Jun-2023',
#    'quoteType': 'FUTURE',
#    'symbol': 'LE=F',
#    'index': 'quotes',
#    'score': 30077.0,
# ...

# %%
get_yahoo_shortname("DE")
# Out:
# {'explains': [],
#  'count': 20,
#  'quotes': [{'exchange': 'NYQ',
#    'shortname': 'Deere & Company',
#    'quoteType': 'EQUITY',
#    'symbol': 'DE',
#    'index': 'quotes',
#    'score': 2865900.0,
#    'typeDisp': 'Equity',
#    'longname': 'Deere & Company',
#    'exchDisp': 'NYSE',
#    'sector': 'Industrials',
#    'industry': 'Farm & Heavy Construction Machinery',
#    'dispSecIndFlag': False,
#    'isYahooFinance': True},
#   {'exchange': 'NMS',
#    'shortname': 'Advanced Micro Devices, Inc.',
#    'quoteType': 'EQUITY',
#    'symbol': 'AMD',
#    'index': 'quotes',
#    'score': 175505.0,
#    'typeDisp': 'Equity',
#    'longname': 'Advanced Micro Devices, Inc.',
#    'exchDisp': 'NASDAQ',
#    'sector': 'Technology',
#    'industry': 'Semiconductors',
#    'isYahooFinance': True},
#   {'exchange': 'NMS',
#    'shortname': 'Icahn Enterprises L.P. - Deposi',
#    'quoteType': 'EQUITY',
#    'symbol': 'IEP',
#    'index': 'quotes',
#    'score': 86812.0,
# ...

# %%
 fn.Ticker("DE").info
# Out:
# {'address1': 'One John Deere Place',
#  'city': 'Moline',
#  'state': 'IL',
#  'zip': '61265',
#  'country': 'United States',
#  'phone': '309 765 4491',
#  'fax': '309 765 4663',
#  'website': 'https://www.deere.com',
#  'industry': 'Farm & Heavy Construction Machinery',
#  'industryDisp': 'Farm & Heavy Construction Machinery',
#  'sector': 'Industrials',
# ...
